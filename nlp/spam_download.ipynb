# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding='latin-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.sample(4)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 34    spam  Thanks for your subscription to Ringtone UK yo...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 2354   ham               R we going with the  &lt;#&gt;  bus?        NaN
# 1816   ham       Are you going to write ccna exam this week??        NaN
#
#      Unnamed: 3 Unnamed: 4
# 34          NaN        NaN
# 5568        NaN        NaN
# 2354        NaN        NaN
# 1816        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.sample(3)
# Out:
#        v1                                                 v2
# 4090  ham  Hey doc pls I want to get nice t shirt for my ...
# 478   ham     K, can I pick up another 8th when you're done?
# 4238  ham  Sez, hows u & de arab boy? Hope u r all good g...

# %%
df.rename(columns={'v1': 'target', 'v2': 'text'}, inplace=True)

# %%
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'] = df['target'].map({'ham': 0, 'spam': 1})
# encoder.fit_transform(df['target'])

# %%
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df = df.drop_duplicates(keep='first')
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %%
df.sample()
# Out:
#       target                                               text
# 2690       1  sports fans - get the latest sports news str* ...

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham', 'spam'], autopct="%0.2f%%")
plt.show()

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\N I T R O
# [nltk_data]    |     V15/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to C:\Users\N I T R O
# [nltk_data]    |     V15/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\N I T R O V15/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\N I T R O V15/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\N I T R O V15/nltk_data...
# ...

# %%
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df['text'][2]
# Out:
# "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"

# %%
len(df['text'][2])
# Out:
# 155

# %%
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df['num_characters'] = df['text'].apply(len)
# Out:
# C:\Windows\Temp\ipykernel_5668\253964734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_characters'] = df['text'].apply(len)

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters
# 0                111
# 1                 29
# 2                155
# 3                 49
# 4                 61
# ...              ...
# 5567             161
# ...

# %%
df['text'].apply(lambda x: len(nltk.word_tokenize(x))).head()
# Out:
# 0    24
# 1     8
# 2    37
# 3    13
# 4    15
# Name: text, dtype: int64

# %%
df['num_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
df
# Out:
# C:\Windows\Temp\ipykernel_5668\2971413714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# ...

# %%
df['num_sentences'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))
# Out:
# C:\Windows\Temp\ipykernel_5668\589552786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_sentences'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sentences
# 0                111         24              2
# 1                 29          8              2
# 2                155         37              2
# ...

# %%
df[df['target'] == 0][['text', 'num_characters', 'num_words', 'num_sentences']].sample(5)
# Out:
#                                                    text  num_characters  \
# 3279  Badrith is only for chennai:)i will surely pic...              79
# 3446  Sitting ard nothing to do lor. U leh busy w work?              49
# 4492  LOL .. *grins* .. I'm not babe, but thanks for...              62
# 490   Sorry man my account's dry or I would, if you ...             120
# 5472  Well obviously not because all the people in m...              79
#
#       num_words  num_sentences
# 3279         20              1
# 3446         13              2
# 4492         18              2
# 490          28              1
# 5472         17              1

# %%
df[df['target'] == 0][['text', 'num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
df[df['target'] == 1][['text', 'num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
df.corr(numeric_only=True)
# Out:
#                   target  num_characters  num_words  num_sentences
# target          1.000000        0.384717   0.262912       0.263939
# num_characters  0.384717        1.000000   0.965760       0.624139
# num_words       0.262912        0.965760   1.000000       0.679971
# num_sentences   0.263939        0.624139   0.679971       1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df, hue='target')
plt.show()

# %%
sns.histplot(df[df['target'] == 0]['num_characters'])
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
sns.histplot(df[df['target'] == 1]['num_characters'])
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
sns.histplot(df[df['target'] == 1]['num_words'])
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.histplot(df[df['target'] == 0]['num_words'])
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>
