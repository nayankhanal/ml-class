# %%
import torch

# %% [markdown]
# ### Function:  y = x^2

# %%
def dy_dx(x):
    return 2 * x

dy_dx(3)
# Out:
# 6

# %%
# Now using PyTorch
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %% [markdown]
# ### Function: y = x^2 , z = sin(y)

# %%
import math

def dz_dx(x):
    return 2 * x * math.cos(x**2)


dz_dx(3)
# Out:
# -5.466781571308061

# %%
# Now using PyTorch
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x**2
z = torch.sin(y)

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668)

# %%
y.grad
# Out:
# /var/folders/hg/ybvpz2sd5pxg82v04p1v28w00000gn/T/ipykernel_26697/486760323.py:1: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more information. (Triggered internally at /Users/runner/work/pytorch/pytorch/build/aten/src/ATen/core/TensorBody.h:498.)
#   y.grad

# %% [markdown]
# ### Another Function

# %%
x = torch.tensor(6.0)  # input feature
y = torch.tensor(0.0)  # true label (binary)

w = torch.tensor(1.0)  # weight
b = torch.tensor(0.0)  # bias

# %%
# binary cross entropy loss for scaler
def binary_cross_entropy_loss(prediction, target):
    epsilon = 1e-8 # to prevent log(0)
    prediction = torch.clamp(prediction, epsilon, 1-epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
# forward pass
z = w * x + b  # weighted sum (linear pass)
y_pred = torch.sigmoid(z)  # predicted probability

# compute binary cross entropy loss
loss = binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(6.0025)

# %%
# backprop / derivatives

# 1. dL/d(y_pred) : Loss with respect to prediction (y_pred)
dloss_dy_pred = (y_pred - y) / (y_pred * (1 - y_pred))

# 2. dy_pred/dz: Prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz = y_pred * (1 - y_pred)

# 3. dz/dw and dz/db: z with respect to w and b
dz_dw = x  # dz/dw = x
dz_db = 1  # dz/db = 1 (bias contributes directly to z)

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual Gradient of loss w.r.t bias (db): {dL_db}")
# Out:
# Manual Gradient of loss w.r.t weight (dw): 5.985164642333984
# Manual Gradient of loss w.r.t bias (db): 0.9975274205207825

# %% [markdown]
# ##### Using AutoGrad

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
z = w*x + b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy_loss(y_pred, y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %%
# Vectors
x = torch.tensor([1,4,6], dtype=torch.float32, requires_grad=True)

# %%
y = (x**2).mean()

# %%
y
# Out:
# tensor(17.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 2.6667, 4.0000])

# %%
# clearing grads
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
# disable gradient tracking
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2

# %%
y.backward()
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
# option 1: requires_grad(False)
# option 2: detach()
# option 3: torch.no_grad()

# %%
# option 1: requires_grad(False)
x.requires_grad_(False)
x
# Out:
# tensor(2.)

# %%
y = x**2
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 y.backward()
#
# File ~/ml/.venv/lib/python3.13/site-packages/torch/_tensor.py:623, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     613 if has_torch_function_unary(self):
#     614     return handle_torch_function(
#     615         Tensor.backward,
#     616         (self,),
#    (...)    621         inputs=inputs,
#     622     )
# --> 623 torch.autograd.backward(
#     624     self, gradient, retain_graph, create_graph, inputs=inputs
#     625 )
#
# File ~/ml/.venv/lib/python3.13/site-packages/torch/autograd/__init__.py:395, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     390     retain_graph = create_graph
#     392 # The reason we repeat the same comment below is that
#     393 # some Python versions print out the first line of a multi-line function
#     394 # calls in the traceback and some print out the last line
# --> 395 _engine_run_backward(
#     396     tensors,
#     397     grad_tensors_,
#     398     retain_graph,
#     399     create_graph,
#     400     inputs_tuple,
#     401     allow_unreachable=True,
#     402     accumulate_grad=True,
#     403 )
#
# File ~/ml/.venv/lib/python3.13/site-packages/torch/autograd/graph.py:979, in _engine_run_backward(t_outputs, *args, **kwargs)
#     976 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     978 try:
# --> 979     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     980         t_outputs, *args, **kwargs
#     981     )  # Calls into the C++ engine to run the backward pass
#     982 finally:
#     983     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
# option 2: detach()
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
z = x.detach()
z
# Out:
# tensor(2.)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y1 = z**2
y1
# Out:
# tensor(4.)

# %%
y.backward()

# %%
y1.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 y1.backward()
#
# File ~/ml/.venv/lib/python3.13/site-packages/torch/_tensor.py:623, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     613 if has_torch_function_unary(self):
#     614     return handle_torch_function(
#     615         Tensor.backward,
#     616         (self,),
#    (...)    621         inputs=inputs,
#     622     )
# --> 623 torch.autograd.backward(
#     624     self, gradient, retain_graph, create_graph, inputs=inputs
#     625 )
#
# File ~/ml/.venv/lib/python3.13/site-packages/torch/autograd/__init__.py:395, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     390     retain_graph = create_graph
#     392 # The reason we repeat the same comment below is that
#     393 # some Python versions print out the first line of a multi-line function
#     394 # calls in the traceback and some print out the last line
# --> 395 _engine_run_backward(
#     396     tensors,
#     397     grad_tensors_,
#     398     retain_graph,
#     399     create_graph,
#     400     inputs_tuple,
#     401     allow_unreachable=True,
#     402     accumulate_grad=True,
#     403 )
#
# File ~/ml/.venv/lib/python3.13/site-packages/torch/autograd/graph.py:979, in _engine_run_backward(t_outputs, *args, **kwargs)
#     976 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     978 try:
# --> 979     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     980         t_outputs, *args, **kwargs
#     981     )  # Calls into the C++ engine to run the backward pass
#     982 finally:
#     983     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
# option 3: torch.no_grad()
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
with torch.no_grad():
    y = x**2

# %%
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 y.backward()
#
# File ~/ml/.venv/lib/python3.13/site-packages/torch/_tensor.py:623, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     613 if has_torch_function_unary(self):
#     614     return handle_torch_function(
#     615         Tensor.backward,
#     616         (self,),
#    (...)    621         inputs=inputs,
#     622     )
# --> 623 torch.autograd.backward(
#     624     self, gradient, retain_graph, create_graph, inputs=inputs
#     625 )
#
# File ~/ml/.venv/lib/python3.13/site-packages/torch/autograd/__init__.py:395, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     390     retain_graph = create_graph
#     392 # The reason we repeat the same comment below is that
#     393 # some Python versions print out the first line of a multi-line function
#     394 # calls in the traceback and some print out the last line
# --> 395 _engine_run_backward(
#     396     tensors,
#     397     grad_tensors_,
#     398     retain_graph,
#     399     create_graph,
#     400     inputs_tuple,
#     401     allow_unreachable=True,
#     402     accumulate_grad=True,
#     403 )
#
# File ~/ml/.venv/lib/python3.13/site-packages/torch/autograd/graph.py:979, in _engine_run_backward(t_outputs, *args, **kwargs)
#     976 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     978 try:
# --> 979     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     980         t_outputs, *args, **kwargs
#     981     )  # Calls into the C++ engine to run the backward pass
#     982 finally:
#     983     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn
