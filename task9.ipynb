# %% [markdown]
# <a href="https://colab.research.google.com/github/nayankhanal/ml-class/blob/tasks/task9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# •	Write a Python function using def to return the product of any count of numbers that is passed as an argument to the function.

# %%
def product(*nums):
  result = 1

  for n in nums:
    result *= n
  return result

print(product(1,2,3,4,5))
# Out:
# 120

# %% [markdown]
# •	Create a function that takes a string and returns its length.

# %%
def length(txt):
  return len(txt)

print(length("asdas"))
# Out:
# 5

# %% [markdown]
# •	Write a function that checks if a given number is divisible by 7 or not.

# %%
def check_if_div_by_7(num):
  return num%7 == 0

print(check_if_div_by_7(13))
print(check_if_div_by_7(14))
# Out:
# False
# True

# %% [markdown]
# •	Define a function that takes a list and returns the maximum value in the list.

# %%
def max_value(nums):
  return max(nums)

print(max_value([1,2,4,5,3]))
# Out:
# 5

# %% [markdown]
# •	Use map() to square only even numbers in a list [1, 2, 3, 4, 5].

# %%
lst = [1, 2, 3, 4, 5]
sqr_srt = list(map(lambda n: n**2 if n%2==0 else n, lst))
print(sqr_srt)
# Out:
# [1, 4, 3, 16, 5]

# %% [markdown]
# •	Use filter() to extract even numbers from a list [1, 2, 3, 4, 5, 6, 7, 8].

# %%
new_lst = [1, 2, 3, 4, 5, 6, 7, 8]
fltr_lst = list(filter(lambda n: n%2==0, new_lst))
print(fltr_lst)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# •	Use reduce() from functools to calculate the product of a list [1, 2, 3, 4, 5].

# %%
from functools import reduce

prod_lst = [1, 2, 3, 4, 5]
prod = reduce(lambda x,y: x*y, prod_lst)
print(prod)
# Out:
# 120

# %% [markdown]
# •	Convert a list of strings to uppercase using map().

# %%
strings = ['my','name','is','nayan']

upr = list(map(lambda s: s.upper(), strings))
print(upr)
# Out:
# ['MY', 'NAME', 'IS', 'NAYAN']

# %% [markdown]
# •	Use filter() to get all words with length greater than 3 from ["hi", "hello", "world", "yes"].

# %%
lst = ["hi", "hello", "world", "yes"]

len_lst = list(filter(lambda s: len(s)>3, lst))
print(len_lst)
# Out:
# ['hello', 'world']

# %% [markdown]
# •	Write a lambda function to add 10 to a given number.

# %%
add_ten = lambda num: num+10

print(add_ten(5))
# Out:
# 15

# %% [markdown]
# •	Create a lambda function that returns the cube of a number.

# %%
cube = lambda num: num**3

print(cube(3))
# Out:
# 27

# %% [markdown]
# •	Write a lambda function to check if a number is divisible by 9.

# %%
check = lambda num: num%9==0

print(check(18))
# Out:
# True

# %% [markdown]
# •	Use a lambda function with map() to double each element in [2, 4, 6, 8].

# %%
lst = [2, 4, 6, 8]
lst = list(map(lambda num: num*2, lst))
print(lst)
# Out:
# [4, 8, 12, 16]

# %% [markdown]
# •	Use a lambda function with filter() to get numbers greater than 5 from [1, 4, 6, 7, 9].

# %%
lst = [1, 4, 6, 7, 9]
greater_than_5 = list(filter(lambda num: num>5, lst))
print(greater_than_5)
# Out:
# [6, 7, 9]

# %% [markdown]
# •	Create a class Mobile with attributes brand and model, and a method to display them.

# %%
class Mobile:
  brand = "Apple"
  model = "Iphone 17"

  def get_brand(self):
    return self.brand

  def get_model(self):
    return self.model

mobile = Mobile()
print(mobile.get_brand())
print(mobile.get_model())
# Out:
# Apple
# Iphone 17

# %% [markdown]
# •	Define a class Student with name and age attributes and a method to print them.

# %%
class Student:
  name = "hari"
  age = "32"

  def print_name_age(self):
    print(f"Name: {self.name} \nAge: {self.age}")

student = Student()
student.print_name_age()
# Out:
# Name: hari
# Age: 32

# %% [markdown]
# •	Create a class Rectangle with a method to calculate the area.

# %%
class Rectange:
  def area(self,l,b):
    return l*b

rect = Rectange()
rect.area(2,3)
# Out:
# 6

# %% [markdown]
# •	Implement a Person class with a private variable __salary and a method to get its value.

# %%
class Person:
  __salary = 5000

  def get_salary(self):
    return self.__salary

person = Person()
person.get_salary()
# Out:
# 5000

# %% [markdown]
# •	Create two different classes with a method describe(), then call the method on objects of both classes.

# %%
class One:
  def describe(self):
    print("One")

class Two:
  def describe(self):
    print("Two")

one = One()
two = Two()

one.describe()
two.describe()
# Out:
# One
# Two

# %% [markdown]
# •	Create a class Person with attributes name and age, and a method to display the information.

# %%
class Student:
  name = "hari"
  age = "32"

  def print_name_age(self):
    print(f"Name: {self.name} \nAge: {self.age}")

student = Student()
student.print_name_age()
# Out:
# Name: hari
# Age: 32

# %% [markdown]
# •	Write a function that takes different objects (Rectangle, Circle, Square) and calls their area() method.

# %%
class Rectange:
  def area(self,l,b):
    return l*b

class Circle:
  def area(self,r):
    return (22/7)*(r**2)

class Square:
  def area(self,l):
    return l**2

rect = Rectange()
print(rect.area(2,3))

rect = Circle()
print(rect.area(3))

rect = Circle()
print(rect.area(5))
# Out:
# 6
# 28.285714285714285
# 78.57142857142857

# %% [markdown]
# •	Define a class Book with title and author attributes and a method to display book details.

# %%
class Book:
  title = "Romeo Julliet"
  author = "William Shakespeare"

  def book_details(self):
    print(f"Title: {self.title} \nAuthor: {self.author}")

book = Book()
book.book_details()
# Out:
# Title: Romeo Julliet
# Author: William Shakespeare

# %% [markdown]
# •	Implement a class Calculator with methods for addition, subtraction, multiplication, and division.

# %%
class Calculator:
  def addition(self,a,b):
    return a+b

  def subtraction(self,a,b):
    return a-b

  def multiplication(self,a,b):
    return a*b

  def division(self,a,b):
    return a/b

calc = Calculator()

print(calc.addition(5,2))
print(calc.subtraction(5,2))
print(calc.multiplication(5,2))
print(calc.division(5,2))
# Out:
# 7
# 3
# 10
# 2.5

# %% [markdown]
# •	Use the ABC module to define an abstract class Shape with an abstract method calculate_area() and implement it in Circle and Rectangle subclasses.

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):
  def calculate_area(self):
    """Must be implemented by all subclasses"""
    pass

class Circle(Shape):
  def __init__(self, radius):
    self.radius = radius

  def calculate_area(self):
    return math.pi * (self.radius**2)


class Rectangle(Shape):
  def __init__(self, length, breadth):
    self.length = length
    self.breadth = breadth

  def calculate_area(self):
    return self.length * self.breadth


circle = Circle(3)
rectangle = Rectangle(3,5)

print(circle.calculate_area())
print(rectangle.calculate_area())
# Out:
# 28.274333882308138
# 15
